# %%
# 판다스 라이브러리
# 데이터 분석을 위한 pandas
# 수치계산을 위한 numpy
# 데이터 시각화를 위한 seaborn

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 경고 메시지는 출력되지 않게 합니다.
import warnings
warnings.filterwarnings("ignore")

# 구버전의 주피터 노트북에서 그래프가 보이는 설정
# %matplotlib inline

# 아나콘다에서 folium 을 사용하기 위해서는 별도의 설치가 필요
# https://anaconda.org/conda-forge/folium
# conda install -c conda-forge folium 
# 지도 시각화를 위한 라이브러리
import folium

# %%
# 한글폰트를 설정합니다.
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# 상가업소정보_201912_01
df2 = pd.read_csv("상가업소정보_201912_01.csv", sep='|')
df2.shape
# Out:
# (573680, 39)

# %%
# 모든 컬럼이 표시되도록 max_columns 의 수를 지정

pd.options.display.max_columns = 39

# %%
df2.head()
# Out:
#      상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0  19905471         와라와라호프         NaN         Q       음식       Q09      유흥주점
# 1  19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12    커피점/카페
# 2  19911801           프로포즈         NaN         Q       음식       Q09      유흥주점
# 3  19912201       싱싱커피&토스트         NaN         Q       음식       Q07     패스트푸드
# 4  19932756       가락사우나내스낵         NaN         F    생활서비스       F09  대중목욕탕/휴게
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드                  표준산업분류명  시도코드    시도명  \
# 0    Q09A01        호프/맥주   I56219                   기타 주점업    11  서울특별시
# 1    Q12A01  커피전문점/카페/다방   I56220                 비알콜 음료점업    11  서울특별시
# 2    Q09A01        호프/맥주   I56219                   기타 주점업    11  서울특별시
# 3    Q07A10        토스트전문   I56192  피자, 햄버거, 샌드위치 및 유사 음식점업    26  부산광역시
# 4    F09A02   사우나/증기탕/온천   S96121                      욕탕업    11  서울특별시
#
# ...

# %%
# tail 로 미리보기
df2.tail()
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 573675  16394290   비파티세리공덕  NaN         Q        음식       Q01            한식
# 573676  16336474     앤탑PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573677  16336218  오즈아레나PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573678  16335152    파인트리네일  NaN         F     생활서비스       F01       이/미용/건강
# 573679  16335150    마이리틀네일  NaN         F     생활서비스       F01       이/미용/건강
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드      표준산업분류명  시도코드    시도명  시군구코드  시군구명  \
# 573675    Q01A01  한식/백반/한정식   I56111      한식 음식점업    11  서울특별시  11440   마포구
# 573676    N01A01     인터넷PC방   R91222  컴퓨터 게임방 운영업    11  서울특별시  11200   성동구
# 573677    N01A01     인터넷PC방   R91222  컴퓨터 게임방 운영업    11  서울특별시  11680   강남구
# 573678    F01A02     발/네일케어   S96119        기타미용업    11  서울특별시  11560  영등포구
# 573679    F01A02     발/네일케어   S96119        기타미용업    11  서울특별시  11320   도봉구
#
# ...

# %%
# 컬럼값만 보기
df2.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
# 데이터프레임의 정보보기
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573680 entries, 0 to 573679
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     573680 non-null  int64
#  1   상호명        573679 non-null  object
#  2   지점명        76674 non-null   object
#  3   상권업종대분류코드  573680 non-null  object
#  4   상권업종대분류명   573680 non-null  object
#  5   상권업종중분류코드  573680 non-null  object
#  6   상권업종중분류명   573680 non-null  object
#  7   상권업종소분류코드  573680 non-null  object
#  8   상권업종소분류명   573680 non-null  object
#  9   표준산업분류코드   539290 non-null  object
#  10  표준산업분류명    539290 non-null  object
#  11  시도코드       573680 non-null  int64
#  12  시도명        573680 non-null  object
#  13  시군구코드      573680 non-null  int64
#  14  시군구명       573680 non-null  object
#  15  행정동코드      573680 non-null  int64
#  16  행정동명       573680 non-null  object
#  17  법정동코드      573680 non-null  int64
#  18  법정동명       573680 non-null  object
# ...

# %%
df2["상권업종대분류명"]
# Out:
# 0               음식
# 1               음식
# 2               음식
# 3               음식
# 4            생활서비스
#             ...
# 573675          음식
# 573676    관광/여가/오락
# 573677    관광/여가/오락
# 573678       생활서비스
# 573679       생활서비스
# Name: 상권업종대분류명, Length: 573680, dtype: object

# %%
# "상권업종대분류명" 이 "음식인 데이터만 가져오기
# df_food 라는 변수에 담아줍니다. 서브셋을 새로운 변수에 저장할 때 copy()를 사용하는 것을 권장합니다.

df_medical = df2[df2["상권업종대분류명"] == "의료"].copy()
df_medical.head()
# Out:
#        상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 38   20024149  타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 52   20350610  한귀원정신과의원  NaN         S       의료       S01       병원    S01B99
# 99   20755460  헬로스마일소아과  NaN         S       의료       S01       병원    S01B11
# 122  20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
# 132  20916395    이태형한의원  NaN         S       의료       S01       병원    S01B06
#
#     상권업종소분류명 표준산업분류코드 표준산업분류명  시도코드    시도명  시군구코드 시군구명       행정동코드    행정동명  \
# 38     내과/외과   Q86201   일반 의원    11  서울특별시  11680  강남구  1168065600    도곡2동
# 52      기타병원      NaN     NaN    26  부산광역시  26500  수영구  2650078000    광안3동
# 99       소아과   Q86201   일반 의원    11  서울특별시  11680  강남구  1168052100    논현1동
# 122  정형/성형외과   Q86201   일반 의원    11  서울특별시  11680  강남구  1168054500    압구정동
# 132      한의원   Q86203     한의원    11  서울특별시  11350  노원구  1135062500  중계2.3동
#
# ...

# %%
# 시군구명이 "강남구" 인 데이터만 가져옵니다.

df2[df2["시군구명"] == "강남구"].head()
# Out:
#       상가업소번호             상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0   19905471          와라와라호프         NaN         Q       음식       Q09
# 1   19911397   커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 26  20014818              쉼터         NaN         Q       음식       Q04
# 27  20015136  배제현의웰빙낙지한마리수제비         NaN         Q       음식       Q03
# 38  20024149        타워광명내과의원         NaN         S       의료       S01
#
#    상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드      표준산업분류명  시도코드    시도명  시군구코드  \
# 0      유흥주점    Q09A01        호프/맥주   I56219       기타 주점업    11  서울특별시  11680
# 1    커피점/카페    Q12A01  커피전문점/카페/다방   I56220     비알콜 음료점업    11  서울특별시  11680
# 26       분식    Q04A01       라면김밥분식   I56194  분식 및 김밥 전문점    11  서울특별시  11680
# 27   일식/수산물    Q03A13       낙지/오징어   I56111      한식 음식점업    11  서울특별시  11680
# 38       병원    S01B07        내과/외과   Q86201        일반 의원    11  서울특별시  11680
#
#    시군구명       행정동코드  행정동명       법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  \
# ...

# %%
# 이번에는 시군구명이 "강남구" 이고 "상권업종대분류명" 이 "음식"인 서브셋을 가져온 후 
# "상권업종중분류명" 별로 빈도수를 구합니다.

df2[(df2["시군구명"] == "강남구") & 
   (df2["상권업종대분류명"] == "")]["상권업종중분류명"].value_counts()
# Out:
# Series([], Name: 상권업종중분류명, dtype: int64)

# %%
# 이번에는 시군구명이 "강남구" 이고 "상권업종대분류명" 이 "음식"인 서브셋을 가져온 후 
# "상권업종중분류명" 별로 빈도수를 구합니다.

df2[(df2["시군구명"] == "강남구") & 
   (df2["상권업종대분류명"] == "의료")]["상권업종중분류명"].value_counts()
# Out:
# 병원          2564
# 약국/한약방       383
# 수의업           88
# 유사의료업         85
# 의료관련서비스업      16
# Name: 상권업종중분류명, dtype: int64

# %%
# df_seoul_food 에 "시도명"이 "서울특별시" 이고 "상권업종대분류명" 이 "음식" 에 대한 서브셋만 가져와서 담아줍니다.

df_seoul_medical = df2[(df2["시도명"] == "서울특별시") & (df2["상권업종대분류명"] == "의료")].copy()
df_seoul_medical.shape
# Out:
# (19011, 39)

# %%
# "시군구명", "상권업종중분류명" 으로 그룹화 해서 상점수를 세어봅니다.
# 결과를 food_gu 에 담아 재사용할 예정입니다.

medical_gu = df_seoul_medical.groupby(["시군구명", "상권업종중분류명"])["상호명"].count()
medical_gu.head()
# Out:
# 시군구명  상권업종중분류명
# 강남구   병원          2564
#       수의업           88
#       약국/한약방       383
#       유사의료업         85
#       의료관련서비스업      16
# Name: 상호명, dtype: int64

# %%
# df_seoul_food 에 "시도명"이 "서울특별시" 이고 "상권업종대분류명" 이 "음식" 에 대한 서브셋만 가져와서 담아줍니다.

df_medical_edu = df2[(df2["시도명"] == "서울특별시") & (df2["상권업종대분류명"] == "의료")].copy()
df_medical_edu.shape
# Out:
# (19011, 39)

# %%
# "시군구명", "상권업종중분류명" 으로 그룹화 해서 상점수를 세어봅니다.
# 결과를 food_gu 에 담아 재사용할 예정입니다.

medical_gu = df_seoul_medical.groupby(["시군구명", "상권업종중분류명"])["상호명"].count()
medical_gu.head()
# Out:
# 시군구명  상권업종중분류명
# 강남구   병원          2564
#       수의업           88
#       약국/한약방       383
#       유사의료업         85
#       의료관련서비스업      16
# Name: 상호명, dtype: int64

# %%
medical_gu.unstack().iloc[:50, :50]
# Out:
# 상권업종중분류명      병원   수의업  약국/한약방  유사의료업  의료관련서비스업
# 시군구명
# 강남구       2564.0  88.0   383.0   85.0      16.0
# 강동구        496.0  36.0   118.0   41.0      14.0
# 강북구        259.0  21.0   105.0   10.0       1.0
# 강서구        587.0  44.0   140.0   24.0      12.0
# 관악구        396.0  33.0   124.0   20.0       6.0
# 광진구        603.0  55.0   219.0   53.0       8.0
# 구로구        289.0  19.0   104.0   31.0       8.0
# 금천구        174.0  12.0    88.0   24.0       6.0
# 노원구        503.0  38.0   172.0   21.0       8.0
# 도봉구        274.0  34.0    85.0   16.0       2.0
# 동대문구       645.0  29.0   447.0   33.0       1.0
# 동작구        346.0  23.0    98.0   22.0       4.0
# 마포구        457.0  35.0   144.0   12.0       2.0
# 서대문구       380.0  29.0   123.0   12.0       NaN
# 서초구       1200.0  44.0   200.0   48.0       3.0
# 성동구        340.0  29.0    92.0   20.0       2.0
# 성북구        472.0  44.0   162.0   34.0       NaN
# 송파구        753.0  43.0   193.0   24.0      13.0
# ...

# %%
# food_gu 에 담긴 데이터를 시각화 합니다.
# 상권업종중분류명 과 상점수 로 barplot을 그립니다.

medical_gu.unstack().loc["강남구"].plot.bar()
# Out:
# <AxesSubplot:xlabel='상권업종중분류명'>

# %%
medical = medical_gu.reset_index()
medical = medical.rename(columns={"상호명":"상호수"})
medical.head()
# Out:
#   시군구명  상권업종중분류명   상호수
# 0  강남구        병원  2564
# 1  강남구       수의업    88
# 2  강남구    약국/한약방   383
# 3  강남구     유사의료업    85
# 4  강남구  의료관련서비스업    16

# %%
plt.figure(figsize=(15, 4))
sns.barplot(data=medical, x="상권업종중분류명", y="상호수")
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='상호수'>

# %%
# catplot을 사용하여 서브프롯을 그립니다.

sns.catplot(data=medical, x="시군구명", y="상호수", 
            kind="bar", col="상권업종중분류명", col_wrap=4)

# %%
# 시도명이 서울로 시작하는 데이터만 봅니다.
# 또, df_seoul 이라는 변수에 결과를 저장합니다.
# 새로운 변수에 데이터프레임을 할당할 때 copy()를 사용하는 것을 권장합니다.

df_seoul = df2[df2["시도명"] == "서울특별시"].copy()
print(df_seoul.shape)
df_seoul.head()
# Out:
# (407376, 39)
#      상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0  19905471         와라와라호프         NaN         Q       음식       Q09      유흥주점
# 1  19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12    커피점/카페
# 2  19911801           프로포즈         NaN         Q       음식       Q09      유흥주점
# 4  19932756       가락사우나내스낵         NaN         F    생활서비스       F09  대중목욕탕/휴게
# 5  19983535            초밥왕         NaN         Q       음식       Q03    일식/수산물
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드   표준산업분류명  시도코드    시도명  시군구코드 시군구명  \
# 0    Q09A01        호프/맥주   I56219    기타 주점업    11  서울특별시  11680  강남구
# 1    Q12A01  커피전문점/카페/다방   I56220  비알콜 음료점업    11  서울특별시  11680  강남구
# 2    Q09A01        호프/맥주   I56219    기타 주점업    11  서울특별시  11545  금천구
# 4    F09A02   사우나/증기탕/온천   S96121       욕탕업    11  서울특별시  11710  송파구
# 5    Q03A03     음식점-초밥전문   I56113   일식 음식점업    11  서울특별시  11710  송파구
#
# ...

# %%
df_313[df_313["시군구명"] == "강남구"].count()
# Out:
# 상가업소번호       12670
# 상호명          12670
# 지점명            617
# 상권업종대분류코드    12670
# 상권업종대분류명     12670
# 상권업종중분류코드    12670
# 상권업종중분류명     12670
# 상권업종소분류코드    12670
# 상권업종소분류명     12670
# 표준산업분류코드     10241
# 표준산업분류명      10241
# 시도코드         12670
# 시도명          12670
# 시군구코드        12670
# 시군구명         12670
# 행정동코드        12670
# 행정동명         12670
# 법정동코드        12670
# 법정동명         12670
# 지번코드         12670
# 대지구분코드       12670
# 대지구분명        12670
# 지번본번지        12670
# 지번부번지        10115
# 지번주소         12670
# 도로명코드        12670
# 도로명          12670
# 건물본번지        12670
# 건물부번지          588
# 건물관리번호       12670
# 건물명           7729
# 도로명주소        12670
# 구우편번호        12670
# 신우편번호        12669
# 동정보           1021
# 층정보           8720
# 호정보           1971
# 경도           12670
# 위도           12670
# dtype: int64

# %%
# unique 를 사용하면 중복을 제거한 시군구명을 가져옵니다. 
# 그리고 shape로 갯수를 출력해 봅니다.

df_seoul["시군구명"].unique()
# Out:
# array(['강남구', '금천구', '송파구', '광진구', '강서구', '중구', '서초구', '성북구', '구로구',
#        '영등포구', '서대문구', '동대문구', '노원구', '동작구', '성동구', '관악구', '강동구', '양천구',
#        '종로구', '강북구', '은평구', '중랑구', '도봉구', '마포구', '용산구'], dtype=object)

# %%
# "seoul_open_store.csv" 라는 이름으로 저장합니다.
df_seoul.to_csv("seoul_open_store.csv", index=False)

# %%
# 제대로 저장이 되었는지 같은 파일을 불러와서 확인합니다.
pd.read_csv("seoul_open_store.csv").head()
# Out:
#      상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0  19905471         와라와라호프         NaN         Q       음식       Q09      유흥주점
# 1  19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12    커피점/카페
# 2  19911801           프로포즈         NaN         Q       음식       Q09      유흥주점
# 3  19932756       가락사우나내스낵         NaN         F    생활서비스       F09  대중목욕탕/휴게
# 4  19983535            초밥왕         NaN         Q       음식       Q03    일식/수산물
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드   표준산업분류명  시도코드    시도명  시군구코드 시군구명  \
# 0    Q09A01        호프/맥주   I56219    기타 주점업    11  서울특별시  11680  강남구
# 1    Q12A01  커피전문점/카페/다방   I56220  비알콜 음료점업    11  서울특별시  11680  강남구
# 2    Q09A01        호프/맥주   I56219    기타 주점업    11  서울특별시  11545  금천구
# 3    F09A02   사우나/증기탕/온천   S96121       욕탕업    11  서울특별시  11710  송파구
# 4    Q03A03     음식점-초밥전문   I56113   일식 음식점업    11  서울특별시  11710  송파구
#
#         행정동코드  행정동명       법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  \
# ...

# %%
# '상호명_소문자'컬럼으로  '배스킨|베스킨|baskin|던킨|dunkin'를 가져와 df_31 변수에 담습니다.

df_31 = df_seoul[df_seoul["상권업종대분류명"].str.contains(
    '의료|학문/교육|생활서비스|관광/여가/오락')].copy()
df_31.shape
# Out:
# (129300, 39)

# %%
# '상호명_소문자'컬럼으로  '배스킨|베스킨|baskin|던킨|dunkin'를 가져와 df_31 변수에 담습니다.

df_313 = df_seoul[df_seoul["상권업종대분류명"].str.contains(
    '의료|생활서비스|관광/여가/오락')].copy()
df_313.shape
# Out:
# (97791, 39)

# %%
# '상호명_소문자'컬럼으로  '배스킨|베스킨|baskin|던킨|dunkin'를 가져와 df_31 변수에 담습니다.

df_3 = df_seoul[df_seoul["상권업종대분류명"].str.contains(
    '학문/교육')].copy()
df_3.shape
# Out:
# (31509, 39)

# %%
# 데이터가 제대로 모아졌는지 확인합니다.
# "상권업종대분류명"을  value_counts 를 통해 빈도수를 계산합니다.

df_31["상권업종대분류명"].value_counts()
# Out:
# 생활서비스       67137
# 학문/교육       31509
# 의료          19011
# 관광/여가/오락    11643
# Name: 상권업종대분류명, dtype: int64

# %%
# 데이터가 제대로 모아졌는지 확인합니다.
# "상권업종대분류명"을  value_counts 를 통해 빈도수를 계산합니다.

df_313["상권업종대분류명"].value_counts()
# Out:
# 생활서비스       67137
# 의료          19011
# 관광/여가/오락    11643
# Name: 상권업종대분류명, dtype: int64

# %%
# 데이터가 제대로 모아졌는지 확인합니다.
# "상권업종대분류명"을  value_counts 를 통해 빈도수를 계산합니다.

df_3["상권업종대분류명"].value_counts()
# Out:
# 학문/교육    31509
# Name: 상권업종대분류명, dtype: int64

# %%
# "상권업종대분류명"컬럼에서 isin 기능을 사용해서 "소매", "생활서비스" 인 데이터만 가져옵니다.

df_31[df_31["상권업종대분류명"].isin(["의료", "학문/교육", "생활서비스", "관광/여가/오락"])]
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 4       19932756  가락사우나내스낵  NaN         F     생활서비스       F09      대중목욕탕/휴게
# 38      20024149  타워광명내과의원  NaN         S        의료       S01            병원
# 73      20783574      선경바둑  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 85      20776515  GIA보석교육원  NaN         R     학문/교육       R03    학원-자격/국가고시
# 93      20741628   행운노래연습장  NaN         N  관광/여가/오락       N02      무도/유흥/가무
# ...          ...       ...  ...       ...       ...       ...           ...
# 573664  16335170     남자이야기  NaN         F     생활서비스       F01       이/미용/건강
# 573676  16336474     앤탑PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573677  16336218  오즈아레나PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573678  16335152    파인트리네일  NaN         F     생활서비스       F01       이/미용/건강
# 573679  16335150    마이리틀네일  NaN         F     생활서비스       F01       이/미용/건강
#
# ...

# %%
# "상권업종대분류명"컬럼에서 isin 기능을 사용해서 "소매", "생활서비스" 인 데이터만 가져옵니다.

df_313[df_313["상권업종대분류명"].isin(["의료", "생활서비스", "관광/여가/오락"])]
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 4       19932756  가락사우나내스낵  NaN         F     생활서비스       F09      대중목욕탕/휴게
# 38      20024149  타워광명내과의원  NaN         S        의료       S01            병원
# 73      20783574      선경바둑  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 93      20741628   행운노래연습장  NaN         N  관광/여가/오락       N02      무도/유흥/가무
# 95      20680081  제일목욕탕내이발  NaN         F     생활서비스       F09      대중목욕탕/휴게
# ...          ...       ...  ...       ...       ...       ...           ...
# 573664  16335170     남자이야기  NaN         F     생활서비스       F01       이/미용/건강
# 573676  16336474     앤탑PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573677  16336218  오즈아레나PC방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 573678  16335152    파인트리네일  NaN         F     생활서비스       F01       이/미용/건강
# 573679  16335150    마이리틀네일  NaN         F     생활서비스       F01       이/미용/건강
#
# ...

# %%
# "상권업종대분류명"컬럼에서 isin 기능을 사용해서 "소매", "생활서비스" 인 데이터만 가져옵니다.

df_3[df_3["상권업종대분류명"].isin(["학문/교육"])]
# Out:
#           상가업소번호       상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 85      20776515  GIA보석교육원      NaN         R    학문/교육       R03  학원-자격/국가고시
# 101     20736806     안재형영어      NaN         R    학문/교육       R04       학원-어학
# 121     20769711       정아트      NaN         R    학문/교육       R05   학원-음악미술무용
# 126     20887860     경찰태권도      NaN         R    학문/교육       R07   학원-예능취미체육
# 134     20924451   아트인스튜디오      NaN         R    학문/교육       R05   학원-음악미술무용
# ...          ...       ...      ...       ...      ...       ...         ...
# 573529  16357981   쌤통수학교습소      NaN         R    학문/교육       R01   학원-보습교습입시
# 573654  16368651    골든벨독서실      NaN         R    학문/교육       R10     도서관/독서실
# 573656  16311412  에이디링크연구소      NaN         R    학문/교육       R09        학원기타
# 573661  16368385    도무스링구아      NaN         R    학문/교육       R01   학원-보습교습입시
# 573662  16368341       아소비  고척동아한신점         R    학문/교육       R01   학원-보습교습입시
#
# ...

# %%
# value_counts 로 "브랜드명"의 빈도수를 구합니다.
brand_count = df_31["상권업종대분류명"].value_counts()
brand_count
# Out:
# 생활서비스       67137
# 학문/교육       31509
# 의료          19011
# 관광/여가/오락    11643
# Name: 상권업종대분류명, dtype: int64

# %%
# value_counts 로 "브랜드명"의 빈도수를 구합니다.
brand_count1 = df_3["상권업종대분류명"].value_counts()
brand_count1
# Out:
# 학문/교육    31509
# Name: 상권업종대분류명, dtype: int64

# %%
# normalize=True 로 빈도수의 비율을 구합니다.
df_31["상권업종대분류명"].value_counts(normalize=True).plot.barh()
# Out:
# <AxesSubplot:>

# %%
# normalize=True 로 빈도수의 비율을 구합니다.
df_3["상권업종대분류명"].value_counts(normalize=True).plot.barh()
# Out:
# <AxesSubplot:>

# %%
brand_count.index
# Out:
# Index(['생활서비스', '학문/교육', '의료', '관광/여가/오락'], dtype='object')

# %%
# countplot 을 그립니다.
g = sns.countplot(data=df_31, x="상권업종대분류명")

for i, val in enumerate(brand_count.index):
    g.text(x=i, y=brand_count[i], s=brand_count[i])

# %%
# 시군구명으로 빈도수를 세고 브랜드명으로 색상을 다르게 표현하는 countplot 을 그립니다.
plt.figure(figsize=(15, 4))
g = sns.countplot(data=df_31, x="시군구명", hue="상권업종대분류명")

# %%
# 시군구명으로 빈도수를 세고 브랜드명으로 색상을 다르게 표현하는 countplot 을 그립니다.
plt.figure(figsize=(15, 4))
g = sns.countplot(data=df_3, x="시군구명", hue="상권업종대분류명")

# %%
# 위 그래프에도 숫자를 표시하고 싶다면 그룹화된 연산이 필요합니다.
# value_counts는 Series에만 사용이 가능하기 때문에 groupby 나 pivot_table로 구해볼 수 있습니다.
table_city_brand = df_3.pivot_table(index="시군구명", columns="상권업종대분류명", values="상호명", aggfunc="count")
table_city_brand.head()
# Out:
# 상권업종대분류명  학문/교육
# 시군구명
# 강남구        4005
# 강동구        1585
# 강북구         513
# 강서구        1498
# 관악구        1313

# %%
# 그래프에 숫자를 표시하기 위해서는 하나씩 출력을 해봅니다.
# 데이터프레임을 순회할 수있는 iterrows() 을 사용해 보겠습니다.
# 아래에 출력되는 숫자를 그래프에 표시할 예정입니다.
for i, val in table_city_brand.iterrows():
    dunkin = val["의료"]
    baskin = val["학문/교육"]
    pp = val["생활서비스"]
    ppp = val["관광/여가/오락"]
    print(dunkin, baskin, pp, ppp)
# Out:
# 3136 4005 8286 1248
# 705 1585 2972 560
# 396 513 1501 284
# 807 1498 3375 677
# 579 1313 2650 578
# 938 1848 3732 1028
# 451 1140 2635 438
# 304 701 1955 294
# 742 1582 2261 357
# 411 931 1596 220
# 1155 1051 2444 483
# 493 1050 1634 289
# 650 1007 2701 318
# 544 773 1769 294
# 1495 2103 4166 672
# 483 742 1853 288
# 712 1246 2444 334
# 1026 1797 3285 608
# 576 1881 2538 358
# 734 984 3067 529
# 362 491 1713 346
# 742 1333 2407 375
# 492 638 1437 353
# 579 413 2480 324
# 499 884 2236 388

# %%
plt.figure(figsize=(15, 4))
# 위에서 만든 피봇테이블과 "시군구명"의 순서과 같게 표시되게 하기 위해 order 값을 지정합니다.
g = sns.countplot(data=df_31, x="시군구명", hue="상권업종대분류명", order=table_city_brand.index)

# 여기에서 i 값은 시군구명이라 숫자로 표현해줄 필요가 있습니다.
# 그래서 순서대로 0번부터 찍어줄 수 있도록 index_no 를 만들어 주고 for문을 순회할 때마다 하나씩 증가시킵니다.
index_no = 0
for i, val in table_city_brand.iterrows():
    dunkin = val["의료"]
    baskin = val["학문/교육"]
    pp = val["생활서비스"]
    ppp = val["관광/여가/오락"]
    g.text(x=index_no, y=dunkin, s=dunkin)
    g.text(x=index_no, y=baskin, s=baskin)
    g.text(x=index_no, y=pp, s=pp)
    g.text(x=index_no, y=ppp, s=ppp)
    index_no = index_no + 1

# %%
plt.figure(figsize=(15, 4))
# 위에서 만든 피봇테이블과 "시군구명"의 순서과 같게 표시되게 하기 위해 order 값을 지정합니다.
g = sns.countplot(data=df_313, x="시군구명", hue="상권업종대분류명", order=table_city_brand.index)

# 여기에서 i 값은 시군구명이라 숫자로 표현해줄 필요가 있습니다.
# 그래서 순서대로 0번부터 찍어줄 수 있도록 index_no 를 만들어 주고 for문을 순회할 때마다 하나씩 증가시킵니다.
index_no = 0
for i, val in table_city_brand.iterrows():
    dunkin = val["의료"]
    pp = val["생활서비스"]
    ppp = val["관광/여가/오락"]
    g.text(x=index_no, y=dunkin, s=dunkin)
    g.text(x=index_no, y=pp, s=pp)
    g.text(x=index_no, y=ppp, s=ppp)
    index_no = index_no + 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '의료'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-2ee6537defe2> in <module>
#       7 index_no = 0
# ...

# %%
# Pandas 의 plot 으로 scatterplot 을 그립니다.
df_31[["위도", "경도"]].plot.scatter(x="경도", y="위도")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
# seaborn의 scatterplot 으로 hue에 브랜드명을 지정해서 시각화 합니다.

sns.scatterplot(data=df_31, x="경도", y="위도", hue="상권업종대분류명")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
# seaborn의 scatterplot 으로 hue에 브랜드명을 지정해서 시각화 합니다.

sns.scatterplot(data=df_313, x="경도", y="위도", hue="상권업종대분류명")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
# seaborn의 scatterplot 으로 hue에 브랜드명을 지정해서 시각화 합니다.

sns.scatterplot(data=df_3, x="경도", y="위도", hue="상권업종대분류명")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
# 위에서 그렸던 그래프를 jointplot 으로 kind="hex" 을 사용해 그려봅니다.

sns.jointplot(data=df_31, x="경도", y="위도", kind="hex")

# %%
# 위에서 그렸던 그래프를 jointplot 으로 kind="hex" 을 사용해 그려봅니다.

sns.jointplot(data=df2, x="경도", y="위도", kind="hex")

# %%
# 위에서 그렸던 그래프를 jointplot 으로 kind="hex" 을 사용해 그려봅니다.

sns.jointplot(data=df_3, x="경도", y="위도", kind="hex")

# %%
# 지도의 중심을 지정하기 위해 위도와 경도의 평균을 구합니다. 
lat = df_31["위도"].mean()
long = df_31["경도"].mean()
lat, long
# Out:
# (37.54352565600161, 126.99771002513901)

# %%
df_313["강동구"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '강동구'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-1a5b58ea430d> in <module>
# ----> 1 df_313["강동구"]
#
# ...

# %%
df_31.index
# Out:
# Int64Index([     4,     38,     73,     85,     93,     95,     99,    101,
#                113,    114,
#             ...
#             573659, 573660, 573661, 573662, 573663, 573664, 573676, 573677,
#             573678, 573679],
#            dtype='int64', length=129300)

# %%
df_31.index
# Out:
# Int64Index([     4,     38,     73,     85,     93,     95,     99,    101,
#                113,    114,
#             ...
#             573659, 573660, 573661, 573662, 573663, 573664, 573676, 573677,
#             573678, 573679],
#            dtype='int64', length=129300)

# %%
# jointplot 그리기
sns.jointplot(data=df_31, x="경도", y="위도", kind="kde")

# %%
# jointplot 그리기
sns.jointplot(data=df2, x="경도", y="위도", kind="kde")

# %%
# 구별로 상권업종대분류명 점포수를 구합니다.
# groupby 를 사용하면 구별로 그룹화 해서 점포수를 구할 수 있습니다.
# 그룹화한 결과를 df_cafe_vs 변수에 담아서 재사용합니다.

df_cafe_vs = df_31.groupby(["시군구명", "상권업종대분류명"])["상권업종대분류명"].count()
df_cafe_vs.head()
# Out:
# 시군구명  상권업종대분류명
# 강남구   관광/여가/오락    1248
#       생활서비스       8286
#       의료          3136
#       학문/교육       4005
# 강동구   관광/여가/오락     560
# Name: 상권업종대분류명, dtype: int64

# %%
df_cafe_vs.unstack().iloc[:50, :50]
# Out:
# 상권업종대분류명  관광/여가/오락  생활서비스    의료  학문/교육
# 시군구명
# 강남구           1248   8286  3136   4005
# 강동구            560   2972   705   1585
# 강북구            284   1501   396    513
# 강서구            677   3375   807   1498
# 관악구            578   2650   579   1313
# 광진구           1028   3732   938   1848
# 구로구            438   2635   451   1140
# 금천구            294   1955   304    701
# 노원구            357   2261   742   1582
# 도봉구            220   1596   411    931
# 동대문구           483   2444  1155   1051
# 동작구            289   1634   493   1050
# 마포구            318   2701   650   1007
# 서대문구           294   1769   544    773
# 서초구            672   4166  1495   2103
# 성동구            288   1853   483    742
# 성북구            334   2444   712   1246
# 송파구            608   3285  1026   1797
# 양천구            358   2538   576   1881
# 영등포구           529   3067   734    984
# 용산구            346   1713   362    491
# 은평구            375   2407   742   1333
# 종로구            353   1437   492    638
# ...

# %%
df_31[["시군구명"]]
# Out:
#         시군구명
# 4        송파구
# 38       강남구
# 73       강남구
# 85       강남구
# 93      동대문구
# ...      ...
# 573664   강동구
# 573676   성동구
# 573677   강남구
# 573678  영등포구
# 573679   도봉구
#
# [129300 rows x 1 columns]

# %%
df_313 = df_313[df_313["시군구명"] == "강남구"]

df_313 = df_313.groupby(["시군구명", "상권업종대분류명"])["상권업종대분류명"].count()

df_313.to_frame()
# Out:
#                상권업종대분류명
# 시군구명 상권업종대분류명
# 강남구  관광/여가/오락      1248
#      생활서비스         8286
#      의료            3136

# %%
df_313.unstack().iloc[:50, :50]
